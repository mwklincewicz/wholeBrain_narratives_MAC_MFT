# %%
import pandas as pd
import os
from nilearn import plotting, image, datasets
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
import re
import ipywidgets as widgets
from IPython.display import display
from matplotlib.gridspec import GridSpec
from atlasreader import create_output
from matplotlib.colors import ListedColormap, BoundaryNorm
from nilearn.image import new_img_like
from scipy.ndimage import label
# Out:
# The Python package you are importing, AtlasReader, is licensed under the
# BSD-3 license; however, the atlases it uses are separately licensed under more
# restrictive frameworks.
# By using AtlasReader, you agree to abide by the license terms of the
# individual atlases. Information on these terms can be found online at:
# https://github.com/miykael/atlasreader/tree/master/atlasreader/data

# %%
# CHOOSE

#  --- Set which foundation number to select ---
foundation = 1  # choose 1, 2, 3 ... 7


# results_dir = Path("/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/")

results_dir = Path("/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/")

# %%
# --- Load only files with the chosen foundation number ---
contrast_files = sorted(
    f for f in results_dir.glob("*.nii*")
    if re.search(fr'foundation{foundation}', f.stem.lower())
)

print(f"Found {len(contrast_files)} contrast maps with foundation{foundation}.")
# Out:
# Found 4 contrast maps with foundation1.

# %%
contrast_files
# Out:
# [PosixPath('/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.19_SecondLevel_tunnel_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz'),
#  PosixPath('/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.21_SecondLevel_piemanpni_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz'),
#  PosixPath('/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.32_SecondLevel_21styear_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz'),
#  PosixPath('/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_inf_SecondLevel_bronx_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz')]

# %%
output_dir = "perStory"

# # atlas reader
create_output(
    contrast_files[1],
    cluster_extent=1,
    direction="pos"
)


# --- Call your function and save output there ---
output = create_output(
    contrast_files[1],
    cluster_extent=1,
    direction="pos"
)

# --- Example: save it inside perStory folder ---
output_path = os.path.join(output_dir, "contrast1_output.nii.gz")
output.to_filename(output_path)
# Out:
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
