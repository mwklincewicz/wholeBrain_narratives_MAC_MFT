# %%
import pandas as pd
import os
from nilearn import plotting, image, datasets
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
import re
import ipywidgets as widgets
from IPython.display import display
from matplotlib.gridspec import GridSpec
from atlasreader import create_output
from matplotlib.colors import ListedColormap, BoundaryNorm
from nilearn.image import new_img_like
from scipy.ndimage import label
# Out:
# The Python package you are importing, AtlasReader, is licensed under the
# BSD-3 license; however, the atlases it uses are separately licensed under more
# restrictive frameworks.
# By using AtlasReader, you agree to abide by the license terms of the
# individual atlases. Information on these terms can be found online at:
# https://github.com/miykael/atlasreader/tree/master/atlasreader/data

# %%
virtueORvice = 'virtues' # vices, virtues

for whichStory in ["21styear","tunnel","milkyway","shapessocial","shapesphysical","prettymouth"]:

    print('run story: ',whichStory)
    
    for whichFoundation in ['1','2','3','4','5','6','7']:

        print('run foundation' ,whichFoundation)

        if whichFoundation == '1':
            FoundationName = 'deference'

        if whichFoundation == '2':
            FoundationName = 'fairness'

        if whichFoundation == '3':
            FoundationName = 'family'

        if whichFoundation == '4':
            FoundationName = 'group'

        if whichFoundation == '5':
            FoundationName = 'heroism'

        if whichFoundation == '6':
            FoundationName = 'property'

        if whichFoundation == '7':
            FoundationName = 'reciprocity'
    
        # output directory
        base_dir1 = os.path.expanduser(
            "~/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/result_interpretation/"
        )
        
        output_dir = Path(f"{base_dir1}{virtueORvice}/vsBaseline/{whichFoundation}/{whichStory}/")
    
        # make the output directory if it does not exist: 
        output_dir.mkdir(parents=True, exist_ok=True)
        
        # results directory
        
        if virtueORvice == 'virtues':
            virtueORviceDataFolder = '7_MAC'
        
        if virtueORvice == 'vices':
            virtueORviceDataFolder = '7_MAC_V'
        
        base_dir2 = os.path.expanduser(
            "~/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/"
        )
        
        results_dir = Path(f"{base_dir2}{whichStory}/{virtueORviceDataFolder}/SecondLevel_contrast/")
        
        contrast_files = sorted(
            results_dir.glob(f"*foundation{whichFoundation}_VsBaseline_fdrcorrect_per_sentence_MAC*")
        )
        
        print(f"Found {len(contrast_files)} contrast maps.")
    
        for f in contrast_files:
            print(f)
            create_output(
                str(f),
                cluster_extent=10,
                direction="pos",
                outdir=str(output_dir)
            )
    
        stat_img = image.load_img(contrast_files[0])
        
        # Extract data and affine
        data = stat_img.get_fdata()
        affine = stat_img.affine
        
        # Label connected clusters
        labeled_array, num_features = label(data > 0)  # detects all nonzero clusters
        
        # Keep only clusters with ≥10 voxels
        filtered_data = np.zeros_like(data)
        for cluster_idx in range(1, num_features + 1):
            cluster_mask = labeled_array == cluster_idx
            if cluster_mask.sum() >= 10:
                filtered_data[cluster_mask] = data[cluster_mask]
        
        # Create filtered image
        filtered_img = image.new_img_like(stat_img, filtered_data)
        
        # Plot
        display = plotting.plot_glass_brain(
            filtered_img,
            colorbar=True,
            display_mode='lyrz',
            plot_abs=False,
            cmap='cold_hot',
            title='fdr corrected (clusters ≥ 10 voxels); ' + FoundationName
        )
        
        
        # Save as PNG
        display.savefig(str(output_dir)+'/glass_brain_clusters_min10vox.png', dpi=300)  
        
        display.close()
# Out:
# run story:  21styear
# run foundation 1
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/21styear/7_MAC/SecondLevel_contrast/threshold_3.08_SecondLevel_21styear_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 2
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/21styear/7_MAC/SecondLevel_contrast/threshold_3.42_SecondLevel_21styear_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 3
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/21styear/7_MAC/SecondLevel_contrast/threshold_2.96_SecondLevel_21styear_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 4
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/21styear/7_MAC/SecondLevel_contrast/threshold_3.15_SecondLevel_21styear_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 5
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/21styear/7_MAC/SecondLevel_contrast/threshold_4.64_SecondLevel_21styear_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 6
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/21styear/7_MAC/SecondLevel_contrast/threshold_4.34_SecondLevel_21styear_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 7
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/21styear/7_MAC/SecondLevel_contrast/threshold_3.57_SecondLevel_21styear_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run story:  tunnel
# run foundation 1
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/tunnel/7_MAC/SecondLevel_contrast/threshold_3.34_SecondLevel_tunnel_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 2
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/tunnel/7_MAC/SecondLevel_contrast/threshold_3.3_SecondLevel_tunnel_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 3
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/tunnel/7_MAC/SecondLevel_contrast/threshold_2.99_SecondLevel_tunnel_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 4
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/tunnel/7_MAC/SecondLevel_contrast/threshold_3.16_SecondLevel_tunnel_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 5
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/tunnel/7_MAC/SecondLevel_contrast/threshold_3.03_SecondLevel_tunnel_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 6
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/tunnel/7_MAC/SecondLevel_contrast/threshold_3.7_SecondLevel_tunnel_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 7
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/tunnel/7_MAC/SecondLevel_contrast/threshold_3.16_SecondLevel_tunnel_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run story:  milkyway
# run foundation 1
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/milkyway/7_MAC/SecondLevel_contrast/threshold_3.01_SecondLevel_milkyway_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 2
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/milkyway/7_MAC/SecondLevel_contrast/threshold_2.69_SecondLevel_milkyway_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 3
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/milkyway/7_MAC/SecondLevel_contrast/threshold_2.84_SecondLevel_milkyway_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 4
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/milkyway/7_MAC/SecondLevel_contrast/threshold_2.7_SecondLevel_milkyway_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 5
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/milkyway/7_MAC/SecondLevel_contrast/threshold_2.85_SecondLevel_milkyway_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 6
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/milkyway/7_MAC/SecondLevel_contrast/threshold_2.76_SecondLevel_milkyway_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 7
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/milkyway/7_MAC/SecondLevel_contrast/threshold_3.31_SecondLevel_milkyway_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run story:  shapessocial
# run foundation 1
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/shapessocial/7_MAC/SecondLevel_contrast/threshold_2.99_SecondLevel_shapessocial_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 2
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/shapessocial/7_MAC/SecondLevel_contrast/threshold_3.05_SecondLevel_shapessocial_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 3
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/shapessocial/7_MAC/SecondLevel_contrast/threshold_2.91_SecondLevel_shapessocial_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 4
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/shapessocial/7_MAC/SecondLevel_contrast/threshold_3.34_SecondLevel_shapessocial_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 5
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/shapessocial/7_MAC/SecondLevel_contrast/threshold_3.11_SecondLevel_shapessocial_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 6
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/shapessocial/7_MAC/SecondLevel_contrast/threshold_3.15_SecondLevel_shapessocial_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 7
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/shapessocial/7_MAC/SecondLevel_contrast/threshold_3.27_SecondLevel_shapessocial_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run story:  shapesphysical
# run foundation 1
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/shapesphysical/7_MAC/SecondLevel_contrast/threshold_3.33_SecondLevel_shapesphysical_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 2
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/shapesphysical/7_MAC/SecondLevel_contrast/threshold_3.66_SecondLevel_shapesphysical_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 3
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/shapesphysical/7_MAC/SecondLevel_contrast/threshold_4.75_SecondLevel_shapesphysical_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 4
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/shapesphysical/7_MAC/SecondLevel_contrast/threshold_3.2_SecondLevel_shapesphysical_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 5
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/shapesphysical/7_MAC/SecondLevel_contrast/threshold_2.92_SecondLevel_shapesphysical_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 6
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/shapesphysical/7_MAC/SecondLevel_contrast/threshold_3.35_SecondLevel_shapesphysical_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 7
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/shapesphysical/7_MAC/SecondLevel_contrast/threshold_3.77_SecondLevel_shapesphysical_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run story:  prettymouth
# run foundation 1
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/prettymouth/7_MAC/SecondLevel_contrast/threshold_3.82_SecondLevel_prettymouth_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 2
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/prettymouth/7_MAC/SecondLevel_contrast/threshold_2.92_SecondLevel_prettymouth_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# run foundation 3
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/prettymouth/7_MAC/SecondLevel_contrast/threshold_3.04_SecondLevel_prettymouth_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 4
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/prettymouth/7_MAC/SecondLevel_contrast/threshold_3.06_SecondLevel_prettymouth_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 5
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/prettymouth/7_MAC/SecondLevel_contrast/threshold_3.31_SecondLevel_prettymouth_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 6
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/prettymouth/7_MAC/SecondLevel_contrast/threshold_2.95_SecondLevel_prettymouth_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# run foundation 7
# Found 1 contrast maps.
# /Users/silvycollin/Library/CloudStorage/GoogleDrive-s.h.p.collin@tilburguniversity.edu/My Drive/research/ongoing/2024_shapesNarrativeMRI/__narratives_and_values_fMRI/wholeBrain_results/processed_first_level_per_sentence/prettymouth/7_MAC/SecondLevel_contrast/threshold_2.76_SecondLevel_prettymouth_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
