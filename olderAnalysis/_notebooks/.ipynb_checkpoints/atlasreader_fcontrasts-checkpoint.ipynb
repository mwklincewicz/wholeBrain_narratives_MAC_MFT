# %%
import pandas as pd
import os
from nilearn import plotting, image, datasets
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
import re
import ipywidgets as widgets
from IPython.display import display
from matplotlib.gridspec import GridSpec
from atlasreader import create_output
from matplotlib.colors import ListedColormap, BoundaryNorm
from nilearn.image import new_img_like
from scipy.ndimage import label
# Out:
# The Python package you are importing, AtlasReader, is licensed under the
# BSD-3 license; however, the atlases it uses are separately licensed under more
# restrictive frameworks.
# By using AtlasReader, you agree to abide by the license terms of the
# individual atlases. Information on these terms can be found online at:
# https://github.com/miykael/atlasreader/tree/master/atlasreader/data

# %%
virtueORvice = 'virtues' # vices, virtues


results_dir = Path(f"/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/{virtueORvice}/fcontrast/")

output_dir = Path(f"/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/atlasreader/{virtueORvice}/")

# %%
contrast_files = sorted(results_dir.glob("*.nii*"))
print(f"Found {len(contrast_files)} contrast maps.")
# Out:
# Found 2 contrast maps.

# %%
contrast_files
# Out:
# [PosixPath('/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/fcontrast/prettymouthaffair_threshold_4.91_bonfcorrect_zscores_fcontrast_secondlevel.nii.gz'),
#  PosixPath('/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/fcontrast/prettymouthparanoia_threshold_4.9_bonfcorrect_zscores_fcontrast_secondlevel.nii.gz')]

# %%
for f in contrast_files:
    print(f)
    create_output(
        str(f),
        cluster_extent=1,
        direction="pos",
        outdir=str(output_dir)
    )
# Out:
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/fcontrast/prettymouthaffair_threshold_4.91_bonfcorrect_zscores_fcontrast_secondlevel.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
# ...

# %% [markdown]
# ## make brain image

# %%
stat_img = image.load_img(contrast_files[0])

# Glass brain view
plotting.plot_glass_brain(
    stat_img,
    colorbar=True,
    display_mode='lyrz',
    plot_abs=False,
    threshold=2.09,  # match threshold bonf 4.91, 2.09 fdr
    cmap='cold_hot',
    title='F-contrast: 21st Year'
)

plt.show()

# %%
stat_img = image.load_img(contrast_files[-1])

# Glass brain view
plotting.plot_glass_brain(
    stat_img,
    colorbar=True,
    display_mode='lyrz',
    plot_abs=False,
    threshold=2.2,  # match threshold 4.91 bonf, 2.2 fdr
    cmap='cold_hot',
    title='F-contrast: Tunnel'
)

plt.show()
