# %%
import pandas as pd
import os
from nilearn import plotting, image, datasets
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
import re
import ipywidgets as widgets
from IPython.display import display
from matplotlib.gridspec import GridSpec
from atlasreader import create_output
from matplotlib.colors import ListedColormap, BoundaryNorm
from nilearn.image import new_img_like
from scipy.ndimage import label

# %%
# results_dir = Path("/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/")
results_dir = Path("/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/")

output_dir = Path("/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/output_perStory/")

# %%
contrast_files = sorted(results_dir.glob("*.nii*"))
print(f"Found {len(contrast_files)} contrast maps.")
# Out:
# Found 42 contrast maps.

# %%
for f in contrast_files:
    print(f)
    create_output(
        str(f),
        cluster_extent=1,
        direction="pos",
        outdir=str(output_dir)
    )
# Out:
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_2.85_SecondLevel_pieman_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_2.94_SecondLevel_merlin_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_2.98_SecondLevel_pieman_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.07_SecondLevel_pieman_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.08_SecondLevel_pieman_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.09_SecondLevel_forgot_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.15_SecondLevel_pieman_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.17_SecondLevel_merlin_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.19_SecondLevel_lucy_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.25_SecondLevel_forgot_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.29_SecondLevel_lucy_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.31_SecondLevel_lucy_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.31_SecondLevel_merlin_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.32_SecondLevel_lucy_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.42_SecondLevel_lucy_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.45_SecondLevel_forgot_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.47_SecondLevel_forgot_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.48_SecondLevel_forgot_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.4_SecondLevel_black_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.61_SecondLevel_lucy_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.69_SecondLevel_forgot_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.72_SecondLevel_black_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.74_SecondLevel_merlin_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.7_SecondLevel_lucy_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.83_SecondLevel_black_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.83_SecondLevel_pieman_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.93_SecondLevel_merlin_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_3.98_SecondLevel_pieman_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_4.24_SecondLevel_black_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_4.38_SecondLevel_forgot_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_4.51_SecondLevel_merlin_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_4.58_SecondLevel_black_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_4.84_SecondLevel_black_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_inf_SecondLevel_black_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_inf_SecondLevel_merlin_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_inf_SecondLevel_slumlordreach_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_inf_SecondLevel_slumlordreach_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_inf_SecondLevel_slumlordreach_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_inf_SecondLevel_slumlordreach_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_inf_SecondLevel_slumlordreach_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_inf_SecondLevel_slumlordreach_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/threshold_inf_SecondLevel_slumlordreach_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVices.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
