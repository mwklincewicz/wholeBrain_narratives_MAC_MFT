# %%
import pandas as pd
import os
from nilearn import plotting, image, datasets
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np
import re
import ipywidgets as widgets
from IPython.display import display
from matplotlib.gridspec import GridSpec
from atlasreader import create_output
from matplotlib.colors import ListedColormap, BoundaryNorm
from nilearn.image import new_img_like
from scipy.ndimage import label
# Out:
# The Python package you are importing, AtlasReader, is licensed under the
# BSD-3 license; however, the atlases it uses are separately licensed under more
# restrictive frameworks.
# By using AtlasReader, you agree to abide by the license terms of the
# individual atlases. Information on these terms can be found online at:
# https://github.com/miykael/atlasreader/tree/master/atlasreader/data

# %%
# results_dir = Path("/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/")
results_dir = Path("/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/vices/")

output_dir = Path("/Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/output_perStory/")

# %%
contrast_files = sorted(results_dir.glob("*.nii*"))
print(f"Found {len(contrast_files)} contrast maps.")
# Out:
# Found 45 contrast maps.

# %%
for f in contrast_files:
    print(f)
    create_output(
        str(f),
        cluster_extent=1,
        direction="pos",
        outdir=str(output_dir)
    )
# Out:
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_2.22_SecondLevel_pieman_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_2.24_SecondLevel_pieman_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_2.36_SecondLevel_pieman_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_2.44_SecondLevel_pieman_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_2.4_SecondLevel_pieman_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_2.55_SecondLevel_pieman_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.12_SecondLevel_black_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.13_SecondLevel_black_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.23_SecondLevel_black_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.31_SecondLevel_black_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.32_SecondLevel_black_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.33_SecondLevel_lucy_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.34_SecondLevel_black_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.37_SecondLevel_forgot_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.39_SecondLevel_merlin_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.41_SecondLevel_lucy_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.43_SecondLevel_merlin_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.47_SecondLevel_merlin_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.4_SecondLevel_forgot_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.4_SecondLevel_lucy_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.52_SecondLevel_merlin_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.57_SecondLevel_merlin_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.64_SecondLevel_black_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.65_SecondLevel_lucy_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.66_SecondLevel_forgot_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.72_SecondLevel_lucy_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.81_SecondLevel_pieman_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.87_SecondLevel_tunnel_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.8_SecondLevel_forgot_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_3.92_SecondLevel_piemanpni_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_4.02_SecondLevel_forgot_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_4.23_SecondLevel_forgot_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_4.42_SecondLevel_merlin_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_4.73_SecondLevel_slumlordreach_foundation7_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_4.97_SecondLevel_slumlordreach_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/atlasreader/atlasreader.py:496: FutureWarning: From release 0.13.0 onwards, this function will, by default, copy the header of the input image to the output. Currently, the header is reset to the default Nifti1Header. To suppress this warning and use the new behavior, set `copy_header=True`.
#   thresh_img = image.threshold_img(stat_img, threshold=voxel_thresh)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_5.16_SecondLevel_piemanpni_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_inf_SecondLevel_forgot_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_inf_SecondLevel_lucy_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_inf_SecondLevel_lucy_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_inf_SecondLevel_merlin_foundation2_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_inf_SecondLevel_slumlordreach_foundation1_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_inf_SecondLevel_slumlordreach_foundation3_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_inf_SecondLevel_slumlordreach_foundation4_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_inf_SecondLevel_slumlordreach_foundation5_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
# /Users/silvycollin/Documents/research/narrativeProject/processed_first_level_per_sentence/virtues/threshold_inf_SecondLevel_slumlordreach_foundation6_VsBaseline_fdrcorrect_per_sentence_MACVirtues.nii.gz
# /opt/anaconda3/envs/renv/lib/python3.12/site-packages/nilearn/plotting/displays/_slicers.py:313: UserWarning: empty mask
#   ims = self._map_show(img, type="imshow", threshold=threshold, **kwargs)
